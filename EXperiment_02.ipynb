# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
x = np.array([3,12,16,33,45,49,57,71,73,80])
y = np.array([7,11,19,24,21,45,56,78,81,85])
z = np.array([73,71,56,54,44,34,32,26,21,8])
p = np.array([55,57,67,72,55,53,45,49,76,45])
plt.plot(x,y)

# %%
plt.plot(x,z)

# %%
plt.plot(x,p)

# %%
plt.plot(y,z)

# %%
plt.title("My first plot ")
plt.xlabel('First value')
plt.ylabel('Second value')
plt.grid()
plt.xticks(range(0,91,5))
plt.yticks(range(0,91,5))
plt.xlim(0,90)
plt.ylim(0,90)
plt.plot(x,y)

# %%
plt.title("My first plot ")
plt.xlabel('First value')
plt.ylabel('Second value')
plt.grid()
plt.xticks(range(0,91,5))
plt.yticks(range(0,91,5))
plt.xlim(0,90)
plt.ylim(0,90)
# o , < > V ^ * D +
plt.plot(x,y,label = '2022',color='cyan',marker = '^')
plt.plot(x,z,label = '2023',color = 'blue',marker = '+')
plt.plot(y,z,label = '2020',color = 'green',marker = '*')
plt.legend()

# %%
plt.figure(figsize=(16,9))
plt.title("My first plot ")
plt.xlabel('First value')
plt.ylabel('Second value')
plt.grid()
plt.plot(x,y,color='brown',marker='o')

# %%
plt.figure(figsize=(16,9))
plt.subplot(1,2,1)
plt.plot(x,y)
plt.subplot(1,2,2)
plt.plot(x,z)

# %%
plt.figure(figsize=(16,9))
plt.subplot(2,2,1)
plt.plot(x,y,color = 'y')
plt.subplot(1,2,2)
plt.plot(x,z,color='r')
plt.subplot(2,2,3)
plt.plot(x,p,color='m')

# %%
df = pd.read_csv('student.csv')
plt.plot(df['age'],df['marks'])

# %%
plt.scatter(x,y)

# %%
df = pd.read_csv('Social_Network_Ads.csv')
df
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
plt.figure(figsize=(16,9))
plt.title('Scatter Plot')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.grid()
plt.scatter(df['Age'],df['EstimatedSalary'],c = df['Purchased'])

# %%
df = pd.read_csv('student.csv')
plt.figure(figsize=(16,9))
plt.grid()
plt.xlabel('Student Name')
plt.ylabel('Makrs')
plt.bar(df['name'],df['marks'],color='orange')
# Out:
# <BarContainer object of 10 artists>

# %%
df['age'].value_counts()
# Out:
# 20    4
# 21    2
# 19    2
# 22    1
# 23    1
# Name: age, dtype: int64

# %%
plt.figure(figsize=(16,9))
plt.grid()
plt.ylabel('Age')
plt.xlabel('count')
plt.barh(df['age'].value_counts().index,df['age'].value_counts(),color= "gray")
# Out:
# <BarContainer object of 5 artists>

# %%
plt.figure(figsize=(16,9))
plt.grid()
plt.ylabel('Age')
plt.xlabel('count')
plt.barh(df['name'],df['marks'],color= "navy")
# Out:
# <BarContainer object of 10 artists>

# %%
df = pd.read_csv('Social_Network_Ads.csv')
plt.figure(figsize=(16,9))
plt.grid()
plt.xlabel('Purchased')
plt.ylabel('Count')
plt.bar(df['Purchased'].value_counts().index,df['Purchased'].value_counts(),color='orange')
# Out:
# <BarContainer object of 2 artists>

# %%
plt.pie(df['Gender'].value_counts(),labels=df['Gender'].value_counts().index,autopct='%2.2f%%');

# %%
plt.xlabel('Ages')
plt.ylabel('Count')
plt.grid()
plt.xticks(range(10,61,10))
plt.hist(df['Age'],bins=range(10,61,10),color = "b")
# Out:
# (array([ 12.,  88., 138., 109.,  53.]),
#  array([10., 20., 30., 40., 50., 60.]),
#  <BarContainer object of 5 artists>)

# %%
plt.xlabel('Salary')
plt.ylabel('Count')
plt.grid()
plt.xticks(range(15000,150000,15000))
plt.hist(df['EstimatedSalary'],bins=range(15000,150000,15000), color = 'k')
# Out:
# (array([53., 53., 61., 67., 78., 21., 25., 20.]),
#  array([ 15000.,  30000.,  45000.,  60000.,  75000.,  90000., 105000.,
#         120000., 135000.]),
#  <BarContainer object of 8 artists>)

# %%
plt.boxplot(df['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x780a2bb79390>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x780a2bb798d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x780a2bb790f0>],
#  'medians': [<matplotlib.lines.Line2D at 0x780a2bb79e10>],
#  'fliers': [<matplotlib.lines.Line2D at 0x780a2bb7a0b0>],
#  'means': []}

# %%
df.loc[156,'Age']
# Out:
# 46.0

# %%
df.loc[256,'Age'] = 100
plt.boxplot(df['Age'])
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x780a2bc03d30>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x780a2bc2c2b0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x780a2bc03a90>],
#  'medians': [<matplotlib.lines.Line2D at 0x780a2bc2c7f0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x780a2bc2ca90>],
#  'means': []}

# %%
x=df[(df['Age'] > 5) & (df['Age']<65)]
x.shape
# Out:
# (398, 5)

# %%
import seaborn as sns
sns.countplot(x=df['Purchased'],palette='pastel')
# Out:
# <ipython-input-125-a911610567b5>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(x=df['Purchased'],palette='pastel')
# <Axes: xlabel='Purchased', ylabel='count'>

# %%
sns.jointplot(x='Age',y='EstimatedSalary',data = df,hue='Purchased')

# %%
iris = sns.load_dataset('iris')
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.pairplot(iris)

# %%
import seaborn as sns
sns.pairlot(iris, hue = 'species')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-133-2965ba66440a> in <cell line: 2>()
#       1 import seaborn as sns
# ----> 2 sns.pairlot(iris, hue = 'species')
#
# AttributeError: module 'seaborn' has no attribute 'pairlot'

# %%
titanic = sns.load_dataset('titanic')
titanic
# Out:
#      survived  pclass     sex   age  sibsp  parch     fare embarked   class  \
# 0           0       3    male  22.0      1      0   7.2500        S   Third
# 1           1       1  female  38.0      1      0  71.2833        C   First
# 2           1       3  female  26.0      0      0   7.9250        S   Third
# 3           1       1  female  35.0      1      0  53.1000        S   First
# 4           0       3    male  35.0      0      0   8.0500        S   Third
# ..        ...     ...     ...   ...    ...    ...      ...      ...     ...
# 886         0       2    male  27.0      0      0  13.0000        S  Second
# 887         1       1  female  19.0      0      0  30.0000        S   First
# 888         0       3  female   NaN      1      2  23.4500        S   Third
# 889         1       1    male  26.0      0      0  30.0000        C   First
# 890         0       3    male  32.0      0      0   7.7500        Q   Third
#
#        who  adult_male deck  embark_town alive  alone
# ...

# %%
sns.countplot(titanic['sex'])
# Out:
# <Axes: xlabel='count', ylabel='sex'>

# %%
sns.countplot(titanic['class']);

# %%
sns.countplot(x=titanic['survived'])
# Out:
# <Axes: xlabel='survived', ylabel='count'>

# %%
sns.boxplot(x='sex',y='survived',data = titanic)
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
sns.barplot(x='sex',y='survived',hue= 'class',data = titanic)
# Out:
# <Axes: xlabel='sex', ylabel='survived'>

# %%
df1 = pd.read_csv('student3.csv')
df1
# Out:
#     roll     name class  marks    age
# 0      1     anil    TE   56.77  22.0
# 1      2     amit    TE   59.77  21.0
# 2      3   aniket    BE   76.88  19.0
# 3      4  ajinkya    TE   69.66  20.0
# 4      5     asha    TE   63.28   NaN
# 5      6   ayesha    BE     NaN  20.0
# 6      7     amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     amol    TE   56.75  20.0
# 9      9     amol    TE   56.75  20.0
# 10    10    anmol    BE   78.66   NaN
# 11    11   surbhi    TE     NaN  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  subhash    be   88.45  21.0
# 14    14   sachin   NaN   59.33  21.0
# 15    15  shalini    TE   63.45  20.0

# %%
df1['age'].mean()
# Out:
# 20.785714285714285

# %%
df1.columns.str.strip()
# Out:
# Index(['roll', 'name', 'class', 'marks', 'age'], dtype='object')

# %%
df1.columns = df.columns.str.strip()
df1.columns
# Out:
# Index(['User ID', 'Gender', 'Age', 'EstimatedSalary', 'Purchased'], dtype='object')

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('student3.csv')
df['class'] = df['class'].str.upper()
df['name']
# Out:
# 0        anil
# 1        amit
# 2      aniket
# 3     ajinkya
# 4        asha
# 5      ayesha
# 6        amar
# 7       Amita
# 8        amol
# 9        amol
# 10      anmol
# 11     surbhi
# 12      Sujay
# 13    subhash
# 14     sachin
# 15    shalini
# Name: name, dtype: object

# %%
df['name'] = df['name'].str.title()
df['name']
# Out:
# 0        Anil
# 1        Amit
# 2      Aniket
# 3     Ajinkya
# 4        Asha
# 5      Ayesha
# 6        Amar
# 7       Amita
# 8        Amol
# 9        Amol
# 10      Anmol
# 11     Surbhi
# 12      Sujay
# 13    Subhash
# 14     Sachin
# 15    Shalini
# Name: name, dtype: object

# %%
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9      True
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# dtype: bool

# %%
df[df.duplicated()]
# Out:
#    roll  name class  marks    age
# 9     9  Amol    TE   56.75  20.0

# %%
df.drop_duplicates(inplace = True)
df.duplicated()
# Out:
# 0     False
# 1     False
# 2     False
# 3     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# dtype: bool

# %%
df.count()
# Out:
# roll      15
# name      15
# class     14
# marks     13
# age       13
# dtype: int64

# %%
df.isnull().sum()
# Out:
# roll      0
# name      0
# class     1
# marks     2
# age       2
# dtype: int64

# %%
df.dropna()
# Out:
#     roll     name class  marks    age
# 0      1     Anil    TE   56.77  22.0
# 1      2     Amit    TE   59.77  21.0
# 2      3   Aniket    BE   76.88  19.0
# 3      4  Ajinkya    TE   69.66  20.0
# 6      7     Amar    BE   65.34  19.0
# 7      8    Amita    BE   68.33  23.0
# 8      9     Amol    TE   56.75  20.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  Subhash    BE   88.45  21.0
# 15    15  Shalini    TE   63.45  20.0

# %%
df = pd.read_csv('student3.csv')
df['marks ']
# Out:
# 0     56.77
# 1     59.77
# 2     76.88
# 3     69.66
# 4     63.28
# 5       NaN
# 6     65.34
# 7     68.33
# 8     56.75
# 9     56.75
# 10    78.66
# 11      NaN
# 12    74.12
# 13    88.45
# 14    59.33
# 15    63.45
# Name: marks , dtype: float64

# %%
df['marks '].fillna(df['marks '].mean())
# Out:
# 0     56.770000
# 1     59.770000
# 2     76.880000
# 3     69.660000
# 4     63.280000
# 5     66.967143
# 6     65.340000
# 7     68.330000
# 8     56.750000
# 9     56.750000
# 10    78.660000
# 11    66.967143
# 12    74.120000
# 13    88.450000
# 14    59.330000
# 15    63.450000
# Name: marks , dtype: float64

# %%
df['age'].fillna(df['age'].median())
# Out:
# 0     22.0
# 1     21.0
# 2     19.0
# 3     20.0
# 4     20.5
# 5     20.0
# 6     19.0
# 7     23.0
# 8     20.0
# 9     20.0
# 10    20.5
# 11    23.0
# 12    22.0
# 13    21.0
# 14    21.0
# 15    20.0
# Name: age, dtype: float64

# %%
df['class']
# Out:
# 0      TE
# 1      TE
# 2      BE
# 3      TE
# 4      TE
# 5      BE
# 6      BE
# 7      be
# 8      TE
# 9      TE
# 10     BE
# 11     TE
# 12     TE
# 13     be
# 14    NaN
# 15     TE
# Name: class, dtype: object

# %%
df['class'].mode()
# Out:
# 0    TE
# Name: class, dtype: object

# %%
df['class'].fillna(df['class'].mode()[0])
# Out:
# 0     TE
# 1     TE
# 2     BE
# 3     TE
# 4     TE
# 5     BE
# 6     BE
# 7     be
# 8     TE
# 9     TE
# 10    BE
# 11    TE
# 12    TE
# 13    be
# 14    TE
# 15    TE
# Name: class, dtype: object

# %%
df.ffill()
# Out:
#     roll     name class  marks    age
# 0      1     anil    TE   56.77  22.0
# 1      2     amit    TE   59.77  21.0
# 2      3   aniket    BE   76.88  19.0
# 3      4  ajinkya    TE   69.66  20.0
# 4      5     asha    TE   63.28  20.0
# 5      6   ayesha    BE   63.28  20.0
# 6      7     amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     amol    TE   56.75  20.0
# 9      9     amol    TE   56.75  20.0
# 10    10    anmol    BE   78.66  20.0
# 11    11   surbhi    TE   78.66  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  subhash    be   88.45  21.0
# 14    14   sachin    be   59.33  21.0
# 15    15  shalini    TE   63.45  20.0

# %%
df.bfill()
# Out:
#     roll     name class  marks    age
# 0      1     anil    TE   56.77  22.0
# 1      2     amit    TE   59.77  21.0
# 2      3   aniket    BE   76.88  19.0
# 3      4  ajinkya    TE   69.66  20.0
# 4      5     asha    TE   63.28  20.0
# 5      6   ayesha    BE   65.34  20.0
# 6      7     amar    BE   65.34  19.0
# 7      8    Amita    be   68.33  23.0
# 8      9     amol    TE   56.75  20.0
# 9      9     amol    TE   56.75  20.0
# 10    10    anmol    BE   78.66  23.0
# 11    11   surbhi    TE   74.12  23.0
# 12    12    Sujay    TE   74.12  22.0
# 13    13  subhash    be   88.45  21.0
# 14    14   sachin    TE   59.33  21.0
# 15    15  shalini    TE   63.45  20.0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('Social_Network_Ads.csv')
plt.figure(figsize=(16,9))##changing aspect ratio.
plt.title('Without scaling')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.grid()
plt.scatter(df['Age'],df['EstimatedSalary'], c = df['Purchased'])

# %%
x = df[['Age','EstimatedSalary']]
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
x_scaled = scaler.fit_transform(x)
x_scaled
# Out:
# array([[0.02380952, 0.02962963],
#        [0.4047619 , 0.03703704],
#        [0.19047619, 0.20740741],
#        [0.21428571, 0.31111111],
#        [0.02380952, 0.45185185],
#        [0.21428571, 0.31851852],
#        [0.21428571, 0.51111111],
#        [0.33333333, 1.        ],
#        [0.16666667, 0.13333333],
#        [0.4047619 , 0.37037037],
#        [0.19047619, 0.48148148],
#        [0.19047619, 0.27407407],
#        [0.04761905, 0.52592593],
#        [0.33333333, 0.02222222],
#        [0.        , 0.4962963 ],
#        [0.26190476, 0.48148148],
#        [0.69047619, 0.07407407],
#        [0.64285714, 0.08148148],
#        [0.66666667, 0.0962963 ],
#        [0.71428571, 0.1037037 ],
#        [0.64285714, 0.05185185],
#        [0.69047619, 0.25185185],
#        [0.71428571, 0.19259259],
#        [0.64285714, 0.05185185],
#        [0.66666667, 0.05925926],
#        [0.69047619, 0.03703704],
#        [0.73809524, 0.0962963 ],
#        [0.69047619, 0.11111111],
# ...

# %%
x_scaled = pd.DataFrame(x_scaled,columns=x.columns)
x_scaled
# Out:
#           Age  EstimatedSalary
# 0    0.023810         0.029630
# 1    0.404762         0.037037
# 2    0.190476         0.207407
# 3    0.214286         0.311111
# 4    0.023810         0.451852
# ..        ...              ...
# 395  0.666667         0.192593
# 396  0.785714         0.059259
# 397  0.761905         0.037037
# 398  0.428571         0.133333
# 399  0.738095         0.155556
#
# [400 rows x 2 columns]

# %%
x_scaled.describe()
# Out:
#               Age  EstimatedSalary
# count  400.000000       400.000000
# mean     0.467976         0.405500
# std      0.249592         0.252570
# min      0.000000         0.000000
# 25%      0.279762         0.207407
# 50%      0.452381         0.407407
# 75%      0.666667         0.540741
# max      1.000000         1.000000

# %%
plt.subplot(1,2,1)
plt.title('Without Scaling')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.grid()
plt.scatter(df['Age'],df['EstimatedSalary'], c = df['Purchased'])
plt.legend()

plt.subplot(1,2,2)
plt.title('With Scaling')
plt.xlabel('Age')
plt.ylabel('Salary')
plt.grid()
plt.scatter(df['Age'],df['EstimatedSalary'], c = df['Purchased'])
plt.legend()
# Out:
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
# WARNING:matplotlib.legend:No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
x_scaler = scaler.fit_transform(x)
x_scaled = pd.DataFrame(x_scaled,columns=x.columns)
x_scaled.describe()
# Out:
#               Age  EstimatedSalary
# count  400.000000       400.000000
# mean     0.467976         0.405500
# std      0.249592         0.252570
# min      0.000000         0.000000
# 25%      0.279762         0.207407
# 50%      0.452381         0.407407
# 75%      0.666667         0.540741
# max      1.000000         1.000000

# %%
df = pd.read_csv('student.csv')
df
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
from sklearn.preprocessing import LabelEncoder
le = LabelEncoder()
df['name'] = le.fit_transform(df['name'])
df
# Out:
#    roll  name class  marks  age
# 0     1     6    TE  56.77   22
# 1     2     2    TE  59.77   21
# 2     3     5    BE  76.88   19
# 3     4     0    TE  69.66   20
# 4     5     8    TE  63.28   20
# 5     6     9    BE  49.55   20
# 6     7     1    BE  65.34   19
# 7     8     3    BE  68.33   23
# 8     9     4    TE  56.75   20
# 9    10     7    BE  78.66   21

# %%
pd.get_dummies(df)
# Out:
#    roll  name  marks  age  class_BE  class_TE
# 0     1     6  56.77   22         0         1
# 1     2     2  59.77   21         0         1
# 2     3     5  76.88   19         1         0
# 3     4     0  69.66   20         0         1
# 4     5     8  63.28   20         0         1
# 5     6     9  49.55   20         1         0
# 6     7     1  65.34   19         1         0
# 7     8     3  68.33   23         1         0
# 8     9     4  56.75   20         0         1
# 9    10     7  78.66   21         1         0

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

df = pd.read_csv('Salary_Data.csv')
df
# Out:
#     YearsExperience    Salary
# 0               1.1   39343.0
# 1               1.3   46205.0
# 2               1.5   37731.0
# 3               2.0   43525.0
# 4               2.2   39891.0
# 5               2.9   56642.0
# 6               3.0   60150.0
# 7               3.2   54445.0
# 8               3.2   64445.0
# 9               3.7   57189.0
# 10              3.9   63218.0
# 11              4.0   55794.0
# 12              4.0   56957.0
# 13              4.1   57081.0
# 14              4.5   61111.0
# 15              4.9   67938.0
# 16              5.1   66029.0
# 17              5.3   83088.0
# 18              5.9   81363.0
# 19              6.0   93940.0
# 20              6.8   91738.0
# 21              7.1   98273.0
# 22              7.9  101302.0
# 23              8.2  113812.0
# 24              8.7  109431.0
# 25              9.0  105582.0
# 26              9.5  116969.0
# 27              9.6  112635.0
# 28             10.3  122391.0
# 29             10.5  121872.0

# %%
x = df[['YearsExperience']]
y = df['Salary']
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.grid()
plt.scatter(x,y,color = 'r')

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(x,y)
# Out:
# LinearRegression()

# %%
regressor.coef_
# Out:
# array([9449.96232146])

# %%
regressor.intercept_
# Out:
# 25792.200198668696

# %%
new = pd.DataFrame({
    'YearsExperience':[12,15,17,18,19,20,22,24,25]
})
print(new)
regressor.predict(new)
# Out:
#    YearsExperience
# 0               12
# 1               15
# 2               17
# 3               18
# 4               19
# 5               20
# 6               22
# 7               24
# 8               25
# array([139191.74805613, 167541.63502049, 186441.5596634 , 195891.52198486,
#        205341.48430632, 214791.44662777, 233691.37127068, 252591.29591359,
#        262041.25823505])

# %%
a = 9449.96232146 * 25 + 25792.200198668696
a
# Out:
# 262041.2582351687

# %%
pred = regressor.predict(x)
pred
# Out:
# array([ 36187.15875227,  38077.15121656,  39967.14368085,  44692.12484158,
#         46582.11730587,  53197.09093089,  54142.08716303,  56032.07962732,
#         56032.07962732,  60757.06078805,  62647.05325234,  63592.04948449,
#         63592.04948449,  64537.04571663,  68317.03064522,  72097.0155738 ,
#         73987.00803809,  75877.00050238,  81546.97789525,  82491.9741274 ,
#         90051.94398456,  92886.932681  , 100446.90253816, 103281.8912346 ,
#        108006.87239533, 110841.86109176, 115566.84225249, 116511.83848464,
#        123126.81210966, 125016.80457395])

# %%
plt.xlabel('Experience')
plt.ylabel('Salary')
plt.grid()
plt.scatter(x,y,color = 'r',label = 'actual')
plt.plot(x,pred,color='g',label='predicted')
plt.legend()

# %%
regressor.score(x,y)
# Out:
# 0.9569566641435086

# %%
from sklearn.metrics import r2_score
r2_score(y,pred)
# Out:
# 0.9569566641435086

# %%
from sklearn.metrics import mean_absolute_error
mean_absolute_error(y,pred)
# Out:
# 4644.2012894435375
